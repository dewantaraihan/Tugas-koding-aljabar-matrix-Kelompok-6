# %% [markdown]
# 1. Buat matrix X ukuran 2x2 menggunakan numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import torch

# %%
X = np.array([[6, 2], [10, -5]])
X
# Out:
# array([[ 6,  2],
#        [10, -5]])

# %% [markdown]
# 2. Buat invers dari matrix X dan beri nama Xinv menggunakan numpy

# %%
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[ 0.1 ,  0.04],
#        [ 0.2 , -0.12]])

# %% [markdown]
# 3. Kalikan X dengan Xinv menggunakan numpy

# %%
np.dot(Xinv, X)
# Out:
# array([[ 1.00000000e+00,  4.16333634e-17],
#        [-5.55111512e-17,  1.00000000e+00]])

# %% [markdown]
# 4. Selesaikan persamaan berikut menggunakan numpy, tensorflow dan pytorch

# %% [markdown]
# Numpy

# %%
X = np.array([[4, 2], [-5, -3]])
X
# Out:
# array([[ 4,  2],
#        [-5, -3]])

# %%
Y = np.array([4, -7])
Y
# Out:
# array([ 4, -7])

# %%
solvingNP = np.linalg.solve(X, Y)
solvingNP
# Out:
# array([-1.,  4.])

# %% [markdown]
# Tensorflow

# %%
X = tf.constant([[4., 2.], [-5., -3.]])
X
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[ 4.,  2.],
#        [-5., -3.]], dtype=float32)>

# %%
Y = tf.constant([[4.], [-7.]])
Y
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[ 4.],
#        [-7.]], dtype=float32)>

# %%
solvingTF = tf.linalg.solve(A, B)
solvingTF
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[-0.99999946],
#        [ 3.999999  ]], dtype=float32)>

# %% [markdown]
# Pytorch

# %%
X = torch.tensor([[4., 2.], [-5., -3.]])
X
# Out:
# tensor([[ 4.,  2.],
#         [-5., -3.]])

# %%
Y = torch.tensor([[4.], [-7.]])
Y
# Out:
# tensor([[ 4.],
#         [-7.]])

# %%
solvingPT = torch.linalg.solve(X, Y)
solvingPT
# Out:
# tensor([[-1.],
#         [ 4.]])
