# %% [markdown]
# **Basis, Orthogonal, and Orthonormal Vectors**

# %%
#buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)
i = np.array([1, 0])
print("Vector i =", i)
j = np.array([0, 1])
print("Vector j =", j)

#buktikan bahwa vector i dan vector j itu orthogonal
dot_ij = np.dot(i, j)
print("Dot product i · j =", dot_ij)
print("Vector i dan vector j orthogonal karena dot product nya adalah 0")

#Bagaimana dengan v=(1,2) dan w=(2,-1), apakah juga orthogonal?
v = np.array([1, 2])
print("Vector v =", v)
w = np.array([2, -1])
print("Vector w =", w)
dot_vw = np.dot(v, w)
print("Dot product v · w =", dot_vw)
print("Vector v dan vector w orthogonal karena dot product nya adalah 0")
# Out:
# Vector i = [1 0]
# Vector j = [0 1]
# Dot product i · j = 0
# Vector i dan vector j orthogonal karena dot product nya adalah 0
# Vector v = [1 2]
# Vector w = [ 2 -1]
# Dot product v · w = 0
# Vector v dan vector w orthogonal karena dot product nya adalah 0
