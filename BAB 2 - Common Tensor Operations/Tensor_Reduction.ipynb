# %% [markdown]
# Tensor Reduction

# %% [markdown]
# No. 1

# %%
import numpy as np

# %%
import torch

# %%
import tensorflow as tf

# %% [markdown]
# buat matrix X dengan ukuran 2x3 menggunakan numpy

# %%
X = np.array([[1, 2, 3], [4, 5, 6]])
X
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# hitung berapa hasil penjumlahan elemen matrix X dengan fungsi sum

# %%
X.sum()
# Out:
# np.int64(21)

# %% [markdown]
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow

# %%
X_tf = tf.Variable([[13, 14, 15], [16, 17, 18]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[13, 14, 15],
#        [16, 17, 18]], dtype=int32)>

# %% [markdown]
# No. 2

# %% [markdown]
# hitung hasil penjumlahan seluruh elemen matrix X

# %%
X.sum()
# Out:
# np.int64(21)

# %% [markdown]
# hitung hasil penjumlahan seluruh elemen matrix X_pt

# %%
X_pt = torch.tensor([[7, 8, 9], [10, 11, 12]])
torch.sum(X_pt)
# Out:
# tensor(57)

# %% [markdown]
# hitung hasil penjumlahan seluruh elemen matrix X_tf

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=93>

# %% [markdown]
# No. 3

# %% [markdown]
# hitung hasil penjumlahan matrix X berdasarkan row nya

# %%
X.sum(axis=0)
# Out:
# array([5, 7, 9])

# %% [markdown]
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya

# %%
torch.sum(X_pt, 0)
# Out:
# tensor([17, 19, 21])

# %% [markdown]
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya

# %%
tf.reduce_sum(X_tf, 0)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([29, 31, 33], dtype=int32)>

# %% [markdown]
# No. 4

# %% [markdown]
# hitung hasil penjumlahan matrix X berdasarkan kolom nya

# %%
X.sum(axis=1)
# Out:
# array([ 6, 15])

# %% [markdown]
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya

# %%
torch.sum(X_pt, 1)
# Out:
# tensor([24, 33])

# %% [markdown]
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya

# %%
tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([42, 51], dtype=int32)>

# %% [markdown]
# No. 5

# %% [markdown]
# hitung nilai minimal dari matrix X, X_pt dan X_tf:

# %%
print(f"Minimal X : {X.min()}")
print(f"Minimal X_pt : {torch.min(X_pt)}")
print(f"Minimal f X_tf : {tf.reduce_min(X_tf)}")
# Out:
# Minimal X : 1
# Minimal X_pt : 7
# Minimal f X_tf : 13

# %% [markdown]
# hitung nilai maksimal dari matrix X, X_pt dan X_tf

# %%
print(f"Maksimal X : {X.max()}")
print(f"Maksimal X_pt : {torch.max(X_pt)}")
print(f"Maksimal f X_tf : {tf.reduce_max(X_tf)}")
# Out:
# Maksimal X : 6
# Maksimal X_pt : 12
# Maksimal f X_tf : 18

# %% [markdown]
# hitung nilai rata-rata dari matrix X, X_pt dan X_tf

# %%
print(f"Rata-rata X : {X.mean()}")
print(f"Rata-rata X_pt : {torch.mean(X_pt.float())}")
print(f"Rata-rata X_tf : {tf.reduce_mean(tf.cast(X_tf, tf.float32))}")
# Out:
# Rata-rata X : 3.5
# Rata-rata X_pt : 9.5
# Rata-rata X_tf : 15.5

# %% [markdown]
# No. 6

# %% [markdown]
# hitung hasil perkalian seluruh elemen matrix X

# %%
X.prod()
# Out:
# np.int64(720)

# %% [markdown]
# hitung hasil perkalian seluruh elemen matrix X_pt

# %%
X_pt.prod()
# Out:
# tensor(665280)

# %% [markdown]
# hitung hasil perkalian seluruh elemen matrix X_tf

# %%
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=13366080>
